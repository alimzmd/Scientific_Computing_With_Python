# %% [markdown]
# # Learn String Manipulation_ Building a Cipher

# %% [markdown]
# Variables

# %%
text = 'Hello World'
shift = 3
alphabet = 'AbcdefghijklmnopqrstuvWxyz'

# %% [markdown]
# ### string manipulation and cryptography logic
# #A Caesar cipher is a foundational encryption technique that shifts each letter in a message by a fixed number of positions down the alphabet

# %%
alphabet.find('z')
# Out:
# 25

# %%
index = alphabet.find(text[1])  #not found, then -1
print(index)
# Out:
# 4

# %%
index = alphabet.find(text[0])  #not found, then -1
print(index)
# Out:
# -1

# %%
index = alphabet.find(text[6])  #not found, then -1
print(index)
# Out:
# 22

# %%
print(text.lower())
# Out:
# hello world

# %%
print(text.upper())
# Out:
# HELLO WORLD

# %%
print(text[6].lower())
# Out:
# w

# %%
index = alphabet.find(text[0].lower()) #
print(index)
# Out:
# 7

# %%
shifted=alphabet[index] #7
shifted
# Out:
# 'h'

# %%
shifted=alphabet[index+shift] #10
shifted
# Out:
# 'k'

# %%
for i in text:   
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for char in text:
    print(char)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for char in text:
    index = alphabet.find(char)
    print(char)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for char in text:
    index = alphabet.find(char)
    print(char,index)
# Out:
# H -1
# e 4
# l 11
# l 11
# o 14
#   -1
# W 22
# o 14
# r 17
# l 11
# d 3

# %%
#adding var
for char in text.lower():
    index = alphabet.find(char)
    print(char, index)
    new_index = index + shift
# Out:
# h 7
# e 4
# l 11
# l 11
# o 14
#   -1
# w -1
# o 14
# r 17
# l 11
# d 3

# %% [markdown]
# text = 'Hello World'
# shift = 3
# alphabet = 'AbcdefghijklmnopqrstuvWxyz'

# %%
# text[0] ='a' #not valid

# %%
text = 'Albatross'

# %%
#Go back to the original string by deleting the text reassignment

# %%
#Now you need to create a new_char variable at the end of your loop body. Set its value to alphabet[new_index].
for char in text.lower():
    index = alphabet.find(char)
    print(char, index)
    new_index = index + shift
    new_char= alphabet[new_index]
# Out:
# a -1
# l 11
# b 1
# a -1
# t 19
# r 17
# o 14
# s 18
# s 18

# %%
for char in text.lower():
    index = alphabet.find(char)
    #print(char, index)
    new_index = index + shift
    new_char= alphabet[new_index]
    print(new_char)
    print('char:', char, 'new char:', new_char)
# Out:
# c
# char: a new char: c
# o
# char: l new char: o
# e
# char: b new char: e
# c
# char: a new char: c
# W
# char: t new char: W
# u
# char: r new char: u
# r
# char: o new char: r
# v
# char: s new char: v
# v
# char: s new char: v

# %%
for char in text.lower():
    index = alphabet.find(char)
    new_index = index + shift
    new_char= alphabet[new_index]
    print(new_char)
    print('char:', char, 'new char:', new_char)
# Out:
# c
# char: a new char: c
# o
# char: l new char: o
# e
# char: b new char: e
# c
# char: a new char: c
# W
# char: t new char: W
# u
# char: r new char: u
# r
# char: o new char: r
# v
# char: s new char: v
# v
# char: s new char: v

# %%
encrypted_text=''
for char in text.lower():
    index = alphabet.find(char)
    new_index = index + shift
    new_char= alphabet[new_index]
    #print(new_char)
    #print('char:', char, 'new char:', new_char)

# %%
for char in text.lower():
    print(char == ' ')
    index = alphabet.find(char)
    new_index = index + shift
    encrypted_text= alphabet[new_index]
    print('char:', char, 'encrypted text:', encrypted_text)
# Out:
# False
# char: a encrypted text: c
# False
# char: l encrypted text: o
# False
# char: b encrypted text: e
# False
# char: a encrypted text: c
# False
# char: t encrypted text: W
# False
# char: r encrypted text: u
# False
# char: o encrypted text: r
# False
# char: s encrypted text: v
# False
# char: s encrypted text: v

# %%
for char in text.lower():
    index = alphabet.find(char)
    new_index = index + shift
    encrypted_text = encrypted_text + alphabet[new_index]
    print('char:', char, 'encrypted text:', encrypted_text)
# Out:
# char: a encrypted text: vc
# char: l encrypted text: vco
# char: b encrypted text: vcoe
# char: a encrypted text: vcoec
# char: t encrypted text: vcoecW
# char: r encrypted text: vcoecWu
# char: o encrypted text: vcoecWur
# char: s encrypted text: vcoecWurv
# char: s encrypted text: vcoecWurvv

# %%
for char in text.lower():
    index = alphabet.find(char)
    new_index = index + shift
    encrypted_text += alphabet[new_index]
    print('char:', char, 'encrypted text:', encrypted_text)
# Out:
# char: a encrypted text: ...
# char: l encrypted text: ...
# char: b encrypted text: ...
# char: a encrypted text: ...
# char: t encrypted text: ...
# char: r encrypted text: ...
# char: o encrypted text: ...
# char: s encrypted text: ...
# char: s encrypted text: ...
